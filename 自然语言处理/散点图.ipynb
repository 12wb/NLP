# %%
import ggplot as gp
import pandas as pd
import numpy as np
crime = pd.read_csv("crimeRatesByState2005.csv",engine='python')
print(gp.ggplot(gp.aes(x='murder',y='burglary'),data=crime)+gp.geom_point(color='red'))
# Out:
# <ggplot: (-9223371941846140679)>

# %%
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+i*.5)*(7-i)*flip)
sinplot()


sns.set()  # 默认参数
sinplot()
sns.set_style("whitegrid")
data = np.random.normal(size=(20,6))+np.arange(6)/2
sns.boxplot(data=data)  # 为盒图


sns.set_style("dark")  # 刻度线没有了，背景为深色
sinplot()


sns.set_style("white")  # 背景为白色，没有刻度线了
sinplot()


sinplot()
sns.set_style("ticks")  # 增加横线上的线段


sinplot()
sns.despine()  # 去掉上边和右边的线段和轴

# %%
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
crime = pd.read_csv("crimeRatesByState2005.csv",engine='python')
crime2 = crime[crime.state != "United Ststes"]
crime2 = crime2[crime2.state !="District of Columbia"]
crime2 = crime2.drop(['state'],axis=1)
crime2 = crime2.drop(['population'],axis=1)
g = sns.pairplot(crime2,diag_kind="kde")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np
crime = pd.read_csv("crimeRatesByState2005.csv",engine='python')
print(list(crime.murder))
crime2 = crime[crime.state != "United Ststes"]
crime2 = crime2[crime2.state !="District of Columbia"]
z = list(crime2.population/10000)
colors = np.random.rand(len(list(crime2.murder)))
cm = plt.cm.get_cmap('RdYlBu')
plt.scatter(list(crime2.murder),list(crime2.burglary),s=z,c=z,cmap=cm,linewidths=0.5,alpha=0.5)
plt.xlabel('murder')
plt.ylabel('burglary')
plt.show()
# Out:
# [5.5999999999999996, 8.1999999999999993, 4.7999999999999998, 7.5, 6.7000000000000002, 6.9000000000000004, 3.7000000000000002, 2.8999999999999999, 4.4000000000000004, 35.399999999999999, 5.0, 6.2000000000000002, 1.8999999999999999, 2.3999999999999999, 6.0, 5.7000000000000002, 1.3, 3.7000000000000002, 4.5999999999999996, 9.9000000000000004, 1.3999999999999999, 9.9000000000000004, 2.7000000000000002, 6.0999999999999996, 2.2000000000000002, 7.2999999999999998, 6.9000000000000004, 1.8999999999999999, 2.5, 8.5, 1.3999999999999999, 4.7999999999999998, 7.4000000000000004, 4.5, 6.7000000000000002, 1.1000000000000001, 5.0999999999999996, 5.2999999999999998, 2.2000000000000002, 6.0999999999999996, 3.2000000000000002, 7.4000000000000004, 2.2999999999999998, 7.2000000000000002, 6.2000000000000002, 2.2999999999999998, 1.3, 6.0999999999999996, 3.2999999999999998, 4.4000000000000004, 3.5, 2.7000000000000002]
